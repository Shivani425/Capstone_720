# %%
from faker import Faker
from textblob import TextBlob

fake = Faker()

# Generate 200 customer reviews for a random product
reviews = []
for i in range(200):
    review = fake.paragraph(nb_sentences=3)
    reviews.append(review)

    # Perform sentiment analysis on the reviews
for review in reviews:
    blob = TextBlob(review)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        sentiment = 'positive'
    elif sentiment_score < 0:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'
    print(f'Review: {review}')
    print(f'Sentiment: {sentiment}\n')
# Out:
# Review: Perform chair single within common. Man night woman operation public across. Image six themselves.
# Sentiment: negative
#
# Review: Letter everyone before go director. Opportunity fund recent dog. Dinner most sense artist tree movie.
# Sentiment: positive
#
# Review: Risk business six young nothing. Health conference require class whether eye behind. Sound attorney second green any run.
# Sentiment: negative
#
# Review: If avoid policy. Provide involve have social model practice.
# Sentiment: positive
#
# Review: Less exactly parent particularly allow.
# Sentiment: positive
#
# Review: If save want animal environmental. Involve image light challenge bring worker.
# Sentiment: positive
#
# Review: White claim early Democrat group. Church matter myself mention moment. Future Democrat serious recently.
# Sentiment: negative
#
# Review: There include single seat order raise offer. Beyond option bring leave.
# Sentiment: negative
#
# Review: Wide service central age school if team. Wish first movement end price expert. They perform game cover in. Free true both nearly.
# Sentiment: positive
#
# Review: Believe development only. Hard turn politics health.
# Sentiment: negative
#
# Review: Race worry rather class chance own.
# Sentiment: positive
#
# Review: Against young plan check between level job. Prove represent away born say.
# Sentiment: positive
#
# Review: Heavy wall skin each candidate light kitchen Mrs. His under his capital radio. Drive strong not recent school door yard. Before property case health.
# Sentiment: positive
#
# Review: Four dark out manage least side. Table growth price involve.
# Sentiment: negative
#
# Review: Language actually rather center. Laugh quickly art believe. Few serious analysis seek pass threat.
# Sentiment: neutral
#
# Review: Without wide process whom pressure discuss once. Yourself indeed wife think religious.
# Sentiment: negative
#
# Review: Artist talk measure together. Measure fine draw.
# Sentiment: positive
#
# Review: Yes against life including too mother current. Establish every real store treatment thousand. Table nature decision customer sport.
# Sentiment: positive
#
# Review: Ever skin accept the that red model pretty. Fill together at.
# Sentiment: positive
#
# Review: Point tough computer dinner actually require board. Writer leg very apply treat tough.
# Sentiment: negative
#
# Review: Party expect you almost new. Research concern heart behavior note. Call along he daughter here themselves quality.
# Sentiment: positive
#
# Review: Heart grow prevent itself talk. Song attack bad why build name. Because them budget government since nearly expect science. Point quality Congress.
# Sentiment: negative
#
# Review: Matter outside own window method. Radio such threat eye exist medical book.
# Sentiment: positive
#
# Review: Notice wind suddenly special born campaign. Center finish force beyond foot. Few increase community fine admit before.
# Sentiment: positive
#
# Review: Into cell do appear. Wind truth represent laugh song amount activity. Art peace growth front be respond produce.
# Sentiment: positive
#
# Review: Current event civil century side. Budget crime approach.
# Sentiment: neutral
#
# Review: Air star type perform degree. Should look state lot doctor table television.
# Sentiment: neutral
#
# Review: Court hundred city difference more huge sign response. Energy family use course enough only same such.
# Sentiment: positive
#
# Review: Under scene mention tree. Institution line family late. Senior measure five magazine push anything.
# Sentiment: negative
#
# Review: Power dog ok environmental energy positive. Customer Congress area against. Mission environment attorney face relationship.
# Sentiment: positive
#
# Review: Ten follow idea two executive. Life whose all often modern. Watch attack job. Similar behind bring performance.
# Sentiment: negative
#
# Review: Hard white wait full past knowledge debate. Close may single nature coach voice my summer. Not painting herself series magazine PM factor.
# Sentiment: negative
#
# Review: North probably team reveal address report. Above movement Mr even girl technology admit. Sea tend walk reveal seven value guy able.
# Sentiment: positive
#
# Review: Call camera drop body ten.
# Sentiment: neutral
#
# Review: Start real strong mention turn herself finally. Sing activity age mind only certain have.
# Sentiment: positive
#
# Review: Although coach cup factor. Along again national however write. True evidence region.
# Sentiment: positive
#
# Review: Body fast leader remember group heart. Many concern way participant toward build believe despite.
# Sentiment: positive
#
# Review: Page ahead notice rock able. View could modern performance physical one current offer.
# Sentiment: positive
#
# Review: Throw remember care store. Success mean yet blood attention responsibility sit character.
# Sentiment: negative
#
# Review: Hand tough eight task. Design generation push but pattern. Try suddenly team full situation hope better. Value financial level unit however.
# Sentiment: positive
#
# Review: Box power bring weight. Leave decade quality art start. Always how debate agreement large firm.
# Sentiment: positive
#
# Review: Record election skin fight might court economy. Realize may eye heavy over add travel tonight. Until machine industry through throw.
# Sentiment: negative
#
# Review: Measure fill high notice heavy we room gun. Dinner believe analysis back agreement mention light let.
# Sentiment: positive
#
# Review: Door range take everybody discover key president evidence. Begin address ground. Ball American pretty.
# Sentiment: positive
#
# Review: Again majority throughout believe order. Morning look where national relate.
# Sentiment: neutral
#
# Review: Long practice both accept. Throw too choice lawyer down ask. Their herself kid show goal environment cultural.
# Sentiment: negative
#
# Review: Federal pretty hold when unit real. Individual sell wonder citizen. Free article society fire when reduce teach evening.
# Sentiment: positive
#
# Review: In open true hard majority. Lot southern house woman expert history. Reduce defense should south shake.
# Sentiment: positive
#
# Review: Nice against week least after. Administration imagine but late difficult him. Ever month history ask than push task.
# Sentiment: negative
#
# Review: Attorney goal herself huge event home. Create discussion travel author early the. Quickly natural director term.
# Sentiment: positive
#
# Review: Whole research light program your natural.
# Sentiment: positive
#
# Review: Everyone security consider east me popular. Red game throughout shoulder field. Southern every million reduce education.
# Sentiment: positive
#
# Review: Behind far summer bring continue. Trial similar stage part.
# Sentiment: negative
#
# Review: Conference ability beat experience. Decision try consumer. Than impact light can even nation.
# Sentiment: positive
#
# Review: Young sea good page safe economy.
# Sentiment: positive
#
# Review: Item born use down arrive right. Strategy require research but month blood. Ball partner else key game.
# Sentiment: negative
#
# Review: Benefit simple continue suggest point. Degree operation issue visit claim show office unit.
# Sentiment: neutral
#
# Review: Rather unit go mean. Pattern fact each break budget. Look break believe marriage miss these.
# Sentiment: negative
#
# Review: Decision foreign performance painting war. Agency rate gas with way newspaper.
# Sentiment: negative
#
# Review: Mind major address economy even list education happy. Answer who American choice sort.
# Sentiment: positive
#
# Review: Fill again teach near hour. Agree wife risk my choice capital knowledge. Likely among your group.
# Sentiment: positive
#
# Review: Collection should others country deal possible five. Social trial position important. Service again only attorney.
# Sentiment: positive
#
# Review: Sometimes themselves discuss.
# Sentiment: neutral
#
# Review: Heart thank reason view price soon government size. Candidate have ten up test situation.
# Sentiment: neutral
#
# Review: Water per yet. Spend indeed list protect road.
# Sentiment: neutral
#
# Review: Everything wrong often area cost second short. Need public religious message.
# Sentiment: negative
#
# Review: Professor consumer defense lose. How bill education exist.
# Sentiment: neutral
#
# Review: Almost involve affect cost order rate. Group despite itself sit little feel. Region agency time economic.
# Sentiment: positive
#
# Review: Future bank happy decide president law might. Include staff short.
# Sentiment: positive
#
# Review: Kitchen consumer at necessary agency thousand short.
# Sentiment: neutral
#
# Review: Sense out price age draw option. Stock word allow. Enjoy occur wish audience trade stand. Him perform program admit.
# Sentiment: positive
#
# Review: Early you plant sign participant medical glass. Reduce travel performance too explain crime. Two air seek to computer per.
# Sentiment: positive
#
# Review: Behavior office around follow chance.
# Sentiment: neutral
#
# Review: Then candidate after bring enough. Hospital use whatever say address avoid.
# Sentiment: neutral
#
# Review: Describe employee middle its clearly. Nation where month the finally.
# Sentiment: positive
#
# Review: Day glass cultural any throughout. Often before majority section build society eye. Nation film them interview cost late wait.
# Sentiment: negative
#
# Review: Ready degree something respond official heart. Third case usually prevent.
# Sentiment: negative
#
# Review: Hit service tough late. Include prepare describe guess body traditional.
# Sentiment: negative
#
# Review: Yard beautiful fast heavy notice affect decide.
# Sentiment: positive
#
# Review: Decide develop friend reveal. Wind us thank sea. Responsibility various field before somebody behavior give.
# Sentiment: neutral
#
# Review: Lot with often identify food energy. Along drive month long energy represent. Letter open should still. Dog economic from former field.
# Sentiment: positive
#
# Review: Usually task back see only determine. Science serious somebody on ability their.
# Sentiment: negative
#
# Review: Trouble control through require prove hair film none. Give message speak radio throw. Suggest sense understand significant study.
# Sentiment: positive
#
# Review: When trial describe sign. Huge soldier country firm subject affect resource.
# Sentiment: positive
#
# Review: Imagine cover say conference land friend sure. Almost carry mission. Article member four.
# Sentiment: positive
#
# Review: House effort too candidate say you. Allow away rise. The water leg support lead occur light.
# Sentiment: positive
#
# Review: Standard find true present into message group fill. In very stock century. Of me more develop particularly with.
# Sentiment: positive
#
# Review: Study draw security more share strategy time. Right whose short if fish.
# Sentiment: positive
#
# Review: Accept help just machine real million popular. Participant my certain recently.
# Sentiment: positive
#
# Review: Front resource resource city national go.
# Sentiment: neutral
#
# Review: Particular resource design participant. Traditional write responsibility hotel trouble. Generation involve third I.
# Sentiment: negative
#
# Review: Animal discover movie act. Instead field cause note agreement hard recognize. Little unit account yet phone fly table.
# Sentiment: positive
#
# Review: Order draw southern husband. Himself physical take strategy picture no the.
# Sentiment: neutral
#
# Review: Car customer interview son score through onto. Moment science star exist may.
# Sentiment: neutral
#
# Review: Recently wall prove happy note national assume. Green three ever reveal early.
# Sentiment: positive
#
# Review: Its clearly like senior wide computer. Water drive board clearly. Finally kid land call. Wrong doctor yeah political seem loss.
# Sentiment: negative
#
# Review: Center consider summer buy week interesting door. Himself chair third between instead mother middle method.
# Sentiment: positive
#
# Review: Try kid Mrs economy. Water more let PM kind condition contain.
# Sentiment: positive
#
# Review: Artist marriage better building detail close message.
# Sentiment: positive
#
# Review: Manager speak summer never choice suddenly south. Adult building language find.
# Sentiment: positive
#
# Review: Do letter similar tree point at simple.
# Sentiment: neutral
#
# Review: Nature become both these drop unit. Ground during thing program oil network.
# Sentiment: neutral
#
# Review: Institution simple get score service shoulder. Lay five argue.
# Sentiment: neutral
#
# Review: Office culture go fact.
# Sentiment: neutral
#
# Review: Author produce through religious fall. Simply west week allow.
# Sentiment: neutral
#
# Review: Yeah speech a summer hotel send create. Industry power near public not identify. Free oil join much over fund.
# Sentiment: positive
#
# Review: Effect still character pick part more front. Result tree perhaps factor place often. Throughout accept surface scientist.
# Sentiment: positive
#
# Review: Present low learn stand suggest painting sometimes. Owner citizen draw measure.
# Sentiment: neutral
#
# Review: Boy maybe how back. Future prevent more throw why event baby.
# Sentiment: positive
#
# Review: Lead room teacher industry move institution second deep. Head live garden energy free speak.
# Sentiment: positive
#
# Review: Never chance west focus light. Certain executive what. Federal give do job game.
# Sentiment: positive
#
# Review: Measure old by high. Around continue chair still amount seek investment.
# Sentiment: positive
#
# Review: Car police population.
# Sentiment: neutral
#
# Review: Heavy phone doctor age wear six. Sea talk wind himself note. After husband work go. Course suggest every for present contain.
# Sentiment: negative
#
# Review: Might well community purpose matter hot under. Big spring long young message. Different right world respond news owner. Occur prevent environmental night growth.
# Sentiment: positive
#
# Review: Clearly rise foot whatever actually. Not growth upon subject end environment speak. Financial voice left south employee water score.
# Sentiment: negative
#
# Review: Maintain bit house action view stop name. Stay those when million take. Republican certain see personal collection town one father. Wind smile door meet.
# Sentiment: positive
#
# Review: Stop anything build statement young. Could bank improve. President friend door almost do report pay us.
# Sentiment: positive
#
# Review: Under seek section include like loss feeling.
# Sentiment: neutral
#
# Review: Serve whole onto citizen gas law. This any ten after number. Someone scientist point.
# Sentiment: positive
#
# Review: Use plan central door walk together evening. Your risk close dream yourself magazine.
# Sentiment: neutral
#
# Review: Safe season unit debate special financial crime. High current because product structure water.
# Sentiment: positive
#
# Review: Know member main data throw out. Believe hope performance sense a turn television reason. Hair factor whom feel memory newspaper.
# Sentiment: positive
#
# Review: Human huge ready hit win my evidence. Pick something stuff safe.
# Sentiment: positive
#
# Review: Loss season huge consider nature capital catch foreign. Picture movie detail security. Month difficult along common record.
# Sentiment: negative
#
# Review: Light ahead deep. Station determine message argue wait under.
# Sentiment: positive
#
# Review: Maintain know fine. Hand political by else interview born rich. Material long art term.
# Sentiment: positive
#
# Review: Collection learn partner during bring. Benefit technology reflect with worker respond Mrs. Town nothing personal position ago media boy.
# Sentiment: neutral
#
# Review: Majority way drug sign light determine whom. Talk him about pass if.
# Sentiment: positive
#
# Review: Nothing yourself create here create. Laugh bag hand institution pass many. She theory owner career go.
# Sentiment: positive
#
# Review: Write find decade election kitchen property her. Conference economy less smile. From enter case rock card finally.
# Sentiment: positive
#
# Review: Product radio window throughout wide. Fight doctor these matter develop training.
# Sentiment: negative
#
# Review: Real road idea may. Toward live time that responsibility. Defense line involve large worry.
# Sentiment: positive
#
# Review: Story bed share health tonight rather experience manager. Test indicate truth might.
# Sentiment: neutral
#
# Review: A public person. Commercial tax popular still series whose. Outside whether let know detail water.
# Sentiment: positive
#
# Review: Attention plant up accept talk statement. Window a make.
# Sentiment: neutral
#
# Review: Because hot ten forward executive. Create our strategy large author nation. Physical relate here dream social public miss.
# Sentiment: positive
#
# Review: Spring new fund game yes reflect. Campaign true evidence American main consider. Television best mean.
# Sentiment: positive
#
# Review: Road right radio like exactly economic gas. Red child again should successful.
# Sentiment: positive
#
# Review: Plan reveal issue tend. Number including indeed budget.
# Sentiment: neutral
#
# Review: Box account phone evidence more door create. Goal air reduce sometimes expect financial concern.
# Sentiment: positive
#
# Review: Seek share whether near. Compare court including business reality each lead big. Section too many outside.
# Sentiment: positive
#
# Review: Police staff leave toward growth trade someone. So look rather west. Government attack politics wife matter whatever.
# Sentiment: neutral
#
# Review: Yard professional bring anything wrong continue. Thing available community usually government. Perhaps resource ahead discuss wait second anything.
# Sentiment: negative
#
# Review: Offer open star character tend heavy decide owner. Girl contain modern. Between everything seem reason.
# Sentiment: neutral
#
# Review: May staff section language since least far. Consider figure American.
# Sentiment: negative
#
# Review: Eat important above hand. Local than day feeling purpose. System his place ok born gun building.
# Sentiment: positive
#
# Review: Page all figure participant. Affect along rather economic late.
# Sentiment: negative
#
# Review: Get image age model husband beautiful market. Act arm own control.
# Sentiment: positive
#
# Review: Response rule idea expert. Manager Democrat meeting common start owner.
# Sentiment: negative
#
# Review: This medical attorney specific sure growth catch. Rise hotel service matter down knowledge. Child store ground rather that.
# Sentiment: positive
#
# Review: Tax company better perform spring practice. Ask growth happy poor compare. Long middle technology area economy tend such.
# Sentiment: positive
#
# Review: Throw apply figure particular. Unit prevent carry military although. Garden improve thousand entire information summer purpose.
# Sentiment: positive
#
# Review: Heart economy son no out end certainly. Professional system summer right. Charge especially somebody. In necessary person without.
# Sentiment: positive
#
# Review: Art worker down have. Home job employee eat and pull be. Method list budget even PM have.
# Sentiment: negative
#
# Review: Help contain add interview owner interesting. Almost put fly under stay.
# Sentiment: positive
#
# Review: Center involve require with. Perhaps partner ever together near scientist. Same stop eat east put significant.
# Sentiment: positive
#
# Review: Everything adult glass improve question three. Common feel born college school employee scientist. Air letter think.
# Sentiment: negative
#
# Review: Others check often sign. List try yet more three kid white both.
# Sentiment: positive
#
# Review: Idea full million enough take someone development. Thought describe color between condition.
# Sentiment: positive
#
# Review: Hot keep as remember serve lawyer. Window force mind they clearly goal.
# Sentiment: positive
#
# Review: Key at student goal. Grow win summer include should establish share.
# Sentiment: positive
#
# Review: Safe hot season team. Garden but friend change movement.
# Sentiment: positive
#
# Review: Than receive woman education chance. They reveal represent law treat claim likely. Doctor individual land add. Test place cause upon.
# Sentiment: neutral
#
# Review: Important reality trade benefit. Past free goal.
# Sentiment: positive
#
# Review: During hear election standard minute impact station. Front page themselves program before main. Bad development same. Room size put apply read.
# Sentiment: negative
#
# Review: Nice democratic whole on grow. Baby wish no remain. Prevent century with likely add last rate speak.
# Sentiment: positive
#
# Review: Certainly cell line level easy.
# Sentiment: positive
#
# Review: Girl child attorney. Happen price middle return industry score. Whatever wonder the central education rich miss.
# Sentiment: positive
#
# Review: Attorney southern improve Republican. Political fast civil reveal.
# Sentiment: positive
#
# Review: In almost mission lay begin ready. Source American of pull others mission look statement. Bank share indeed professor.
# Sentiment: positive
#
# Review: Establish safe college treatment increase politics. Stuff raise six however level class learn.
# Sentiment: positive
#
# Review: Play strategy entire throughout small girl son.
# Sentiment: negative
#
# Review: Development production according city beautiful court college. A sort lose research customer century.
# Sentiment: positive
#
# Review: Value choose civil town current knowledge east. Medical career south return picture rule. Entire move cultural say similar admit impact style.
# Sentiment: positive
#
# Review: With gas approach pay main black. Chair someone hit perhaps money decade fall.
# Sentiment: neutral
#
# Review: Action value early note especially kind his individual. Institution executive dark character huge. True though mouth child special. Get morning number.
# Sentiment: positive
#
# Review: Help through population near attention talk base later. Quickly visit result security author evidence trouble. Whom above interesting finish cut modern.
# Sentiment: positive
#
# Review: Strong pay next science. Even difference identify nation board throughout.
# Sentiment: positive
#
# Review: Dark reach federal small officer employee even analysis. Mission firm month trouble music both where. Sure serve agree why class open.
# Sentiment: negative
#
# Review: Weight last medical scene property college others. Attack look stuff nothing local. About southern area medical carry. Technology difficult beautiful.
# Sentiment: positive
#
# Review: Hour generation customer north try western simple. Truth significant discover coach ok. Arrive medical watch beat plan wife single.
# Sentiment: positive
#
# Review: Research stand in tonight grow cultural describe month. Scientist set assume however throw produce myself.
# Sentiment: positive
#
# Review: Charge room development free goal. Friend contain face election set. Stock which pick thought feel public.
# Sentiment: positive
#
# Review: Town get always build number break seem. Nature them science form themselves rest painting. See newspaper money recent answer executive nice. Apply cultural eye under go anyone share.
# Sentiment: positive
#
# Review: Whether page no beyond maybe argue spend build. Money same specific foot.
# Sentiment: neutral
#
# Review: Poor your door put simple person. Who trade letter fly would professional check. Future ability address lose decide. Hair price especially make.
# Sentiment: positive
#
# Review: Happen small low speak. Product really certain sell appear do already specific. Resource learn partner open rich east method every.
# Sentiment: positive
#
# Review: War lot yard cell executive memory. Build air approach affect send conference. Able out sit could tell be. Station condition standard wrong amount world run.
# Sentiment: neutral
#
# Review: Fight message than hundred certainly upon why. Section join young Mrs sell property simply we. Draw system however. Thousand go our suffer most role.
# Sentiment: positive
#
# Review: Good toward citizen future them. Participant feeling provide pick study positive. Player cause send career give tell. Short drive term indicate let.
# Sentiment: positive
#
# Review: East we simple computer building especially rock. Task ability air full.
# Sentiment: positive
#
# Review: On debate head here. Loss health ask cultural according.
# Sentiment: positive
#
# Review: Cost girl surface study economy. Floor only public require ready we reflect.
# Sentiment: positive
#
# Review: Wife get approach fear gas government. Lawyer read ok radio ten pick role here. Main peace series wall without attention training yourself.
# Sentiment: positive
#
# Review: Tax place policy expert laugh move. Necessary notice allow ball. Radio suddenly watch pick throw attention.
# Sentiment: positive
#
# Review: Benefit rate yourself level continue challenge political. She amount smile fear own she. Country organization amount to. When situation hour road go.
# Sentiment: positive
#
# Review: Window area level remain amount almost. Party over political help experience protect capital.
# Sentiment: neutral
#
# Review: Safe issue hundred past. Site discover heavy.
# Sentiment: positive
#
# Review: Scene important last worry voice. Performance mention expert.
# Sentiment: positive
